# %%
import sqlite3
import pandas as pd
from tqdm.notebook import tqdm

# %% [markdown]
# ## NPPES data filtering
# The NPPES dataset contains a large number of fields, only a few of which are relevant to this project:
#
# 'NPI'
# Entity Type, indicated by the 'Entity Type Code' field:
# 1 = Provider (doctors, nurses, etc.)
# 2 = Facility (Hospitals, Urgent Care, Doctors Offices)
# Entity Name: Either First/Last or Organization or Other Organization Name contained in the following fields:
# 'Provider Organization Name (Legal Business Name)'
# 'Provider Last Name (Legal Name)'
# 'Provider First Name'
# 'Provider Middle Name'
# 'Provider Name Prefix Text'
# 'Provider Name Suffix Text'
# 'Provider Credential Text'
# Address: Business Practice Location (not mailing), contained in the following fields:
# 'Provider First Line Business Mailing Address'
# 'Provider Second Line Business Mailing Address'
# 'Provider Business Mailing Address City Name'
# 'Provider Business Mailing Address State Name'
# 'Provider Business Mailing Address Postal Code'
# The provider's taxonomy code, which is contained in one of the 'Healthcare Provider Taxonomy Code*' columns. A provider can have up to 15 taxonomy codes, but we want the one which has Primary Switch = Y in the associated 'Healthcare Provider Primary Taxonomy Switch*' field. Note that this does not always occur in spot 1.

# %%
nppes = pd.DataFrame()

db = sqlite3.connect('data/nppes_lite.sqlite')


def run_query(n):
    query = '''
    SELECT npi, 
    entity_type_code,
    [provider_organization_name_(legal_business_name)],
    [provider_last_name_(legal_name)],
    provider_first_name,
    provider_middle_name,
    provider_name_prefix_text,
    provider_name_suffix_text,
    provider_credential_text,
    provider_first_line_business_mailing_address,
    provider_second_line_business_mailing_address,
    provider_business_mailing_address_city_name,
    provider_business_mailing_address_state_name,
    provider_business_mailing_address_postal_code,
    healthcare_provider_taxonomy_code_{0} AS healthcare_provider_taxonomy_code
    FROM nppes_raw
    WHERE healthcare_provider_primary_taxonomy_switch_{0} = 'Y' AND
    entity_type_code IN (1,2)
    '''.format(n)
    
    nppes = pd.read_sql(query, db)
    return nppes 

for i in range (1,16):
    results = run_query(i)
    nppes = nppes.append(results)

# %% [markdown]
# #### converting a dataframe to a table in the database

# %%
nppes.to_sql('nppes', db, if_exists = 'append', index = False)

# %%
db.close()

# %% [markdown]
# ## Checking if all tables went into db

# %%
db = sqlite3.connect('data/nppes_lite.sqlite')

query= '''
SELECT *
FROM nppes_raw
LIMIT 5
'''
df = pd.read_sql(query, db)
df.head()
# Out:
#           npi  entity_type_code replacement_npi  \
# 0  1841293891               1.0            None
# 1  1659374601               1.0            None
# 2  1699778647               2.0            None
# 3  1134122187               1.0            None
# 4  1003819046               1.0            None
#
#   employer_identification_number_(ein)  \
# 0                                 None
# 1                                 None
# 2                            <UNAVAIL>
# 3                                 None
# 4                                 None
#
#   provider_organization_name_(legal_business_name)  \
# 0                                             None
# 1                                             None
# 2               VISITING HOME HEALTH SERVICES, INC
# 3                                             None
# 4                                             None
#
#   provider_last_name_(legal_name) provider_first_name provider_middle_name  \
# 0                           GIBBS               ELMER               RICKEY
# 1                        OBERDICK               WENDY               TIPTON
# 2                            None                None                 None
# 3                        RUDNICKE              CHERYL               DENISE
# 4                        NYLANDER             BARBARA                    H
#
#   provider_name_prefix_text provider_name_suffix_text  ...  \
# 0                       DR.                      None  ...
# 1                      None                      None  ...
# 2                      None                      None  ...
# 3                      MRS.                      None  ...
# 4                      None                      None  ...
#
#   healthcare_provider_taxonomy_group_7 healthcare_provider_taxonomy_group_8  \
# 0                                 None                                 None
# 1                                 None                                 None
# 2                                 None                                 None
# 3                                 None                                 None
# 4                                 None                                 None
#
#    healthcare_provider_taxonomy_group_9 healthcare_provider_taxonomy_group_10  \
# 0                                  None                                  None
# 1                                  None                                  None
# 2                                  None                                  None
# 3                                  None                                  None
# 4                                  None                                  None
#
#   healthcare_provider_taxonomy_group_11 healthcare_provider_taxonomy_group_12  \
# 0                                  None                                  None
# 1                                  None                                  None
# 2                                  None                                  None
# 3                                  None                                  None
# 4                                  None                                  None
#
#   healthcare_provider_taxonomy_group_13 healthcare_provider_taxonomy_group_14  \
# 0                                  None                                  None
# 1                                  None                                  None
# 2                                  None                                  None
# 3                                  None                                  None
# 4                                  None                                  None
#
#   healthcare_provider_taxonomy_group_15  certification_date
# 0                                  None                None
# 1                                  None                None
# 2                                  None                None
# 3                                  None                None
# 4                                  None                None
#
# [5 rows x 330 columns]

# %%
db = sqlite3.connect('data/nppes_lite.sqlite')

query= '''
SELECT *
FROM hop_team
LIMIT 5
'''
df = pd.read_sql(query, db)
df.head()
# Out:
#      from_npi      to_npi  patient_count  transaction_count  average_day_wait  \
# 0  1033142146  1000000004            491                535            10.232
# 1  1013977990  1003000126            134                145            27.352
# 2  1013996669  1003000126             91                 92            35.152
# 3  1033102504  1003000126             52                 64            15.328
# 4  1003029620  1003000126            111                121            33.058
#
#    std_day_wait
# 0        36.558
# 1        51.137
# 2        68.009
# 3        38.300
# 4        58.981

# %%
db = sqlite3.connect('data/nppes_lite.sqlite')

query= '''
SELECT *
FROM nucc_taxonomy
LIMIT 5
'''
df = pd.read_sql(query, db)
df.head()
# Out:
#          code                             grouping        classification  \
# 0  193200000X                                Group       Multi-Specialty
# 1  193400000X                                Group      Single Specialty
# 2  207K00000X  Allopathic & Osteopathic Physicians  Allergy & Immunology
# 3  207KA0200X  Allopathic & Osteopathic Physicians  Allergy & Immunology
# 4  207KI0005X  Allopathic & Osteopathic Physicians  Allergy & Immunology
#
#                      specialization  \
# 0                              None
# 1                              None
# 2                              None
# 3                           Allergy
# 4  Clinical & Laboratory Immunology
#
#                                           definition effective_date  \
# 0  A business group of one or more individual pra...      10/1/2003
# 1  A business group of one or more individual pra...      10/1/2003
# 2  An allergist-immunologist is trained in evalua...       4/1/2003
# 3                              Definition to come...       4/1/2003
# 4                              Definition to come...       4/1/2003
#
#   deactivation_date last_modified_date  \
# 0              None               None
# 1              None               None
# 2              None           7/1/2007
# 3              None               None
# 4              None               None
#
#                                                notes  \
# 0                                    [7/1/2003: new]
# 1                                    [7/1/2003: new]
# 2  Source: American Board of Medical Specialties,...
# 3                                               None
# 4                                               None
#
#                                         display_name
# 0                              Multi-Specialty Group
# 1                             Single Specialty Group
# 2                     Allergy & Immunology Physician
# 3                                  Allergy Physician
# 4  Clinical & Laboratory Immunology (Allergy & Im...

# %%
db = sqlite3.connect('data/nppes_lite.sqlite')

query= '''
SELECT *
FROM zip_cbsa
LIMIT 5
'''
df = pd.read_sql(query, db)
df.head()
# Out:
#      zip   cbsa  res_ratio  bus_ratio  oth_ratio  tot_ratio
# 0  00501  35620        0.0        1.0        0.0        1.0
# 1  00601  38660        1.0        1.0        1.0        1.0
# 2  00602  10380        1.0        1.0        1.0        1.0
# 3  00603  10380        1.0        1.0        1.0        1.0
# 4  00604  10380        1.0        1.0        1.0        1.0

# %%
db = sqlite3.connect('data/nppes_lite.sqlite')

query= '''
SELECT *
FROM nppes
LIMIT 5
'''
df = pd.read_sql(query, db)
df.head()
# Out:
#           npi  entity_type_code  \
# 0  1841293891               1.0
# 1  1659374601               1.0
# 2  1699778647               2.0
# 3  1134122187               1.0
# 4  1003819046               1.0
#
#   provider_organization_name_(legal_business_name)  \
# 0                                             None
# 1                                             None
# 2               VISITING HOME HEALTH SERVICES, INC
# 3                                             None
# 4                                             None
#
#   provider_last_name_(legal_name) provider_first_name provider_middle_name  \
# 0                           GIBBS               ELMER               RICKEY
# 1                        OBERDICK               WENDY               TIPTON
# 2                            None                None                 None
# 3                        RUDNICKE              CHERYL               DENISE
# 4                        NYLANDER             BARBARA                    H
#
#   provider_name_prefix_text provider_name_suffix_text  \
# 0                       DR.                      None
# 1                      None                      None
# 2                      None                      None
# 3                      MRS.                      None
# 4                      None                      None
#
#   provider_credential_text provider_first_line_business_mailing_address  \
# 0                     M.D.                          49 CLEVELAND ST 310
# 1                       MD                                     PO BOX 9
# 2                     None                             3001 KEITH ST NW
# 3                     CRNP                                PO BOX 440100
# 4                     M.D.                       3024 BUSINESS PARK CIR
#
#   provider_second_line_business_mailing_address  \
# 0                                          None
# 1                                          None
# 2                                          None
# 3                                          None
# 4                                          None
#
#   provider_business_mailing_address_city_name  \
# 0                                  CROSSVILLE
# 1                                   KINGSPORT
# 2                                   CLEVELAND
# 3                                   NASHVILLE
# 4                              GOODLETTSVILLE
#
#   provider_business_mailing_address_state_name  \
# 0                                           TN
# 1                                           TN
# 2                                           TN
# 3                                           TN
# 4                                           TN
#
#    provider_business_mailing_address_postal_code  \
# 0                                    385552854.0
# 1                                    376620009.0
# 2                                    373123713.0
# 3                                    372440100.0
# 4                                    370723132.0
#
#   healthcare_provider_taxonomy_code
# 0                        208600000X
# 1                        207Q00000X
# 2                        251E00000X
# 3                        363L00000X
# 4                        207VG0400X
